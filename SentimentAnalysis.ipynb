# %% [markdown]
# <a href="https://colab.research.google.com/github/darshbs/sentiment-analysis/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = 'Enter your Consumer Key'
consumer_secret = 'Enter your Consumer secret Key'
access_token = 'Enter your access token'
access_token_secret = 'Enter your access token secret'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
public_tweet = api.search_tweets(q="MiamiGP", lang="en")

for tweet in public_tweet:
  print(tweet.text)
  analysis = TextBlob(tweet.text)
  print(analysis.sentiment)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-7-316ab7464385> in <cell line: 0>()
#       7
#       8 api = tweepy.API(auth)
# ----> 9 public_tweet = api.search_tweets(q="MiamiGP", lang="en")
#      10
#      11 for tweet in public_tweet:
#
# /usr/local/lib/python3.11/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      30         @functools.wraps(method)
#      31         def wrapper(*args, **kwargs):
# ---> 32             return method(*args, **kwargs)
#      33         wrapper.pagination_mode = mode
#      34         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      43             kwargs['payload_list'] = payload_list
#      44             kwargs['payload_type'] = payload_type
# ---> 45             return method(*args, **kwargs)
#      46         wrapper.payload_list = payload_list
# ...
